# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Admin\Downloads\Visadataset.csv')

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=df.select_dtypes(include='object')
num=df.select_dtypes(exclude='object')

# %% [markdown]
# **map method**
# - Create a dictionary lables as keys, numbers a values
# - in python index start with -
# - case status has two lables we need two values 0 and 1
# - certified becomes 0
# - denied becomes 1

# %%
df['case_status'].nunique()
# Out:
# 2

# %%
df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Certified':0, 'Denied':1}
df['case_status']=df['case_status'].map(d)

# %%
df['case_status']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
continents=list(df['continent'].unique())

# %%
continent_df={}
for i in range(df['continent'].nunique()):
    continent_df[continents[i]]=i

# %%
continent_df
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
df=pd.read_csv(r'C:\Users\Admin\Downloads\Visadataset.csv')
d={}

labels=df['case_status'].unique()
for i in range(len(labels)):
    d[labels[i]]=i

d
# Out:
# {'Denied': 0, 'Certified': 1}

# %%
d={}
labels=df['continent'].unique()
for i in range(len(labels)):
    d[labels[i]]=i

d
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
d={}
df=pd.read_csv(r'C:\Users\Admin\Downloads\Visadataset.csv')
lables=df['case_status'].unique()
d={lables[i]:i for i in range(len(lables))}
df['case_status']=df['case_status'].map(d)

# %%
d
# Out:
# {'Denied': 0, 'Certified': 1}

# %%
d={}
df=pd.read_csv(r'C:\Users\Admin\Downloads\Visadataset.csv')
lables=df['continent'].unique()
d={lables[i]:i for i in range(len(lables))}
df['continent']=df['continent'].map(d)

# %%
d
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
d={}
df=pd.read_csv(r'C:\Users\Admin\Downloads\Visadataset.csv')
for i in cat[1:]:
    lables=df[i].unique()
    d={lables[i]:i for i in range(len(lables))}
    df[i]=df[i].map(d)

# %%
df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **labelEncoder**
#
# - sickit-learn(sklearn)
#
# - sklearn library is a heart of machine learning in python
#
# - MLlib is a geart of machine learning in pyspark
#
# - sklearn(library)
#
#     - preprocess(class)
#
#         - LabelEncoder(method)
#
# - fit : calculate something
#
# - fit_transform : we are modify the values because of calculated one

# %%
df=pd.read_csv(r'C:\Users\Admin\Downloads\Visadataset.csv')

# %%
from sklearn.preprocessing import LabelEncoder # read the method
le=LabelEncoder()#save the method

le.fit_transform(df[['case_status']])# apply the fit transform
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([1, 0, 1, ..., 0, 0, 0])

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df=pd.read_csv(r'C:\Users\Admin\Downloads\Visadataset.csv')

# %% [markdown]
# **OneHotEncoder**

# %% [markdown]
# |case_status|case_Status_denied|case_status_certified|
# |-----------|-------------------|----------------------|
# |denied|1|0|
# |certifed|0|1|
# |certified|0|1|
# |denied|1|0|

# %% [markdown]
# - OneHotEncoder creates new columns that equal to Number of unique labels
#
# - one Disadvantage is data dimensions will be increased
#
# - More Dimensions leads to more procesing time leads to bigger infra memory
#
# - this is called as **Curse of dimensionality**
#
# - **Advantage**
#
# - Generally ML algorithms excpects no correlation netween input columns
#
# - when one column value available and at a same time another column value not available means
#
#     - both are independent each other

# %%
pd.get_dummies(df['case_id'])
# Out:
#        EZYV01  EZYV02  EZYV03  EZYV04  EZYV05  EZYV06  EZYV07  EZYV08  EZYV09  \
# 0        True   False   False   False   False   False   False   False   False
# 1       False    True   False   False   False   False   False   False   False
# 2       False   False    True   False   False   False   False   False   False
# 3       False   False   False    True   False   False   False   False   False
# 4       False   False   False   False    True   False   False   False   False
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 25475   False   False   False   False   False   False   False   False   False
# 25476   False   False   False   False   False   False   False   False   False
# 25477   False   False   False   False   False   False   False   False   False
# 25478   False   False   False   False   False   False   False   False   False
# 25479   False   False   False   False   False   False   False   False   False
#
# ...

# %%
df=pd.read_csv(r'C:\Users\Admin\Downloads\Visadataset.csv')

# %%
cat=df.select_dtypes(include='object')
num=df.select_dtypes(exclude='object')

# %%
cat=cat.columns

# %%
pd.get_dummies(df,columns=cat[1:])
# Out:
#          case_id  no_of_employees  yr_of_estab  prevailing_wage  \
# 0         EZYV01            14513         2007         592.2029
# 1         EZYV02             2412         2002       83425.6500
# 2         EZYV03            44444         2008      122996.8600
# 3         EZYV04               98         1897       83434.0300
# 4         EZYV05             1082         2005      149907.3900
# ...          ...              ...          ...              ...
# 25475  EZYV25476             2601         2008       77092.5700
# 25476  EZYV25477             3274         2006      279174.7900
# 25477  EZYV25478             1121         1910      146298.8500
# 25478  EZYV25479             1918         1887       86154.7700
# 25479  EZYV25480             3195         1960       70876.9100
#
#        continent_Africa  continent_Asia  continent_Europe  \
# 0                 False            True             False
# 1                 False            True             False
# ...

# %%
pd.get_dummies(df,columns=cat[1:],dtype=int)
# Out:
#          case_id  no_of_employees  yr_of_estab  prevailing_wage  \
# 0         EZYV01            14513         2007         592.2029
# 1         EZYV02             2412         2002       83425.6500
# 2         EZYV03            44444         2008      122996.8600
# 3         EZYV04               98         1897       83434.0300
# 4         EZYV05             1082         2005      149907.3900
# ...          ...              ...          ...              ...
# 25475  EZYV25476             2601         2008       77092.5700
# 25476  EZYV25477             3274         2006      279174.7900
# 25477  EZYV25478             1121         1910      146298.8500
# 25478  EZYV25479             1918         1887       86154.7700
# 25479  EZYV25480             3195         1960       70876.9100
#
#        continent_Africa  continent_Asia  continent_Europe  \
# 0                     0               1                 0
# 1                     0               1                 0
# ...

# %% [markdown]
# - if data is in ordinal fo with LabelEncoder
#
# - if data is Nominal go with OneHotEncoder
#
# - if Labels are more go with LabelEncode
#
# - if labels are less go with OneHotencoder
